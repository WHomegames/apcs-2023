# %% [markdown]
# # 2023 Track - 1600m
# Selected meets...

# %%
import re
finish_regex = re.compile(r"(?P<place>\d+)\.\t(?P<grade>\d+)\t(?P<name>[\w ]+)\t+(?P<time>[0-9:\.]+)a(?P<record>SR|PR)?\n(?P<school>[\w\-\(\) ]+)")

# %%
def read_meet_file(filename):
    with open(filename, 'r') as file:
        content = file.read()

    lines = content.splitlines()
    meet = lines[0]
    date = lines[1]
    gender = lines[2].split(" ")[0]
    finishes = []
    for item in finish_regex.finditer(content):
        finish = item.groupdict()
        finish['place'] = int(finish['place'])
        finish['grade'] = int(finish['grade'])
        finish['meet'] = meet
        finish['date'] = date
        finish['gender'] = gender
        finishes.append(finish)

    return finishes
read_meet_file('datasets/tf-1600/2023-04-08_Womens.txt')
# Out:
# [{'place': 1,
#   'grade': 12,
#   'name': 'Jessica Frydenlund',
#   'time': '5:04.79',
#   'record': None,
#   'school': 'Anacortes',
#   'meet': 'Birger Solberg Invitational',
#   'date': 'Apr 8, 2023',
#   'gender': 'Womens'},
#  {'place': 2,
#   'grade': 11,
#   'name': 'Amelia Severn',
#   'time': '5:09.18',
#   'record': 'SR',
#   'school': 'Shorewood',
#   'meet': 'Birger Solberg Invitational',
#   'date': 'Apr 8, 2023',
#   'gender': 'Womens'},
#  {'place': 3,
#   'grade': 11,
#   'name': 'Aliyah Yearian',
#   'time': '5:09.19',
#   'record': None,
#   'school': 'Port Townsend (East Jefferson)',
#   'meet': 'Birger Solberg Invitational',
#   'date': 'Apr 8, 2023',
#   'gender': 'Womens'},
#  {'place': 4,
#   'grade': 10,
#   'name': 'Selena Bangerter',
#   'time': '5:12.81',
#   'record': 'SR',
#   'school': 'Henry Jackson',
#   'meet': 'Birger Solberg Invitational',
#   'date': 'Apr 8, 2023',
#   'gender': 'Womens'},
#  {'place': 5,
#   'grade': 12,
#   'name': 'Isla Chadsey',
#   'time': '5:17.64',
#   'record': None,
#   'school': 'Northwest',
#   'meet': 'Birger Solberg Invitational',
#   'date': 'Apr 8, 2023',
#   'gender': 'Womens'},
#  {'place': 6,
#   'grade': 10,
#   'name': 'Feron Wallace',
#   'time': '5:24.01',
#   'record': None,
#   'school': 'South Kamloops',
#   'meet': 'Birger Solberg Invitational',
#   'date': 'Apr 8, 2023',
#   'gender': 'Womens'},
#  {'place': 7,
#   'grade': 11,
#   'name': 'Lauren Hoyt',
#   'time': '5:25.23',
#   'record': None,
#   'school': 'Bothell',
#   'meet': 'Birger Solberg Invitational',
#   'date': 'Apr 8, 2023',
#   'gender': 'Womens'},
#  {'place': 8,
#   'grade': 10,
#   'name': 'Riley Eberhardt',
#   'time': '5:27.41',
#   'record': None,
#   'school': 'Issaquah',
#   'meet': 'Birger Solberg Invitational',
#   'date': 'Apr 8, 2023',
#   'gender': 'Womens'},
#  {'place': 9,
#   'grade': 10,
#   'name': 'Hanna Bruno',
#   'time': '5:28.22',
#   'record': None,
#   'school': 'Shorewood',
#   'meet': 'Birger Solberg Invitational',
#   'date': 'Apr 8, 2023',
#   'gender': 'Womens'},
#  {'place': 10,
#   'grade': 9,
#   'name': 'Cassidy Armstrong',
#   'time': '5:29.34',
#   'record': None,
#   'school': 'Ballard',
#   'meet': 'Birger Solberg Invitational',
#   'date': 'Apr 8, 2023',
#   'gender': 'Womens'},
#  {'place': 11,
#   'grade': 10,
#   'name': 'Sydney Harri',
#   'time': '5:29.82',
#   'record': None,
#   'school': 'Sehome',
#   'meet': 'Birger Solberg Invitational',
#   'date': 'Apr 8, 2023',
#   'gender': 'Womens'},
#  {'place': 13,
#   'grade': 9,
#   'name': 'Mayli Tuomisto',
#   'time': '5:35.55',
#   'record': None,
#   'school': 'Juanita',
#   'meet': 'Birger Solberg Invitational',
#   'date': 'Apr 8, 2023',
#   'gender': 'Womens'},
#  {'place': 14,
#   'grade': 10,
#   'name': 'Katie Manly',
#   'time': '5:36.29',
#   'record': None,
#   'school': 'Ferndale',
#   'meet': 'Birger Solberg Invitational',
#   'date': 'Apr 8, 2023',
#   'gender': 'Womens'},
#  {'place': 15,
#   'grade': 11,
#   'name': 'Emme Rousseau',
#   'time': '5:37.60',
#   'record': None,
#   'school': 'Ballard',
#   'meet': 'Birger Solberg Invitational',
#   'date': 'Apr 8, 2023',
#   'gender': 'Womens'},
#  {'place': 17,
#   'grade': 10,
#   'name': 'Clare Mullin',
#   'time': '5:39.61',
#   'record': None,
#   'school': 'Sitka',
#   'meet': 'Birger Solberg Invitational',
#   'date': 'Apr 8, 2023',
#   'gender': 'Womens'},
#  {'place': 18,
#   'grade': 9,
#   'name': 'Clara Michael',
#   'time': '5:41.73',
#   'record': None,
#   'school': 'Issaquah',
#   'meet': 'Birger Solberg Invitational',
#   'date': 'Apr 8, 2023',
#   'gender': 'Womens'},
#  {'place': 19,
#   'grade': 10,
#   'name': 'Abby Rusk',
#   'time': '5:44.19',
#   'record': None,
#   'school': 'Sehome',
#   'meet': 'Birger Solberg Invitational',
#   'date': 'Apr 8, 2023',
#   'gender': 'Womens'},
#  {'place': 20,
#   'grade': 9,
#   'name': 'Scout Lynass',
#   'time': '5:45.15',
#   'record': None,
#   'school': 'Shorecrest',
#   'meet': 'Birger Solberg Invitational',
#   'date': 'Apr 8, 2023',
#   'gender': 'Womens'},
#  {'place': 22,
#   'grade': 12,
#   'name': 'Kaia Szymczak',
#   'time': '5:46.17',
#   'record': None,
#   'school': 'Sehome',
#   'meet': 'Birger Solberg Invitational',
#   'date': 'Apr 8, 2023',
#   'gender': 'Womens'},
#  {'place': 23,
#   'grade': 11,
#   'name': 'Phoebe Bryar',
#   'time': '5:46.25',
#   'record': None,
#   'school': 'Garfield',
#   'meet': 'Birger Solberg Invitational',
#   'date': 'Apr 8, 2023',
#   'gender': 'Womens'},
#  {'place': 24,
#   'grade': 9,
#   'name': 'Vivi Hakim',
#   'time': '5:47.94',
#   'record': 'PR',
#   'school': 'Shorecrest',
#   'meet': 'Birger Solberg Invitational',
#   'date': 'Apr 8, 2023',
#   'gender': 'Womens'},
#  {'place': 25,
#   'grade': 9,
#   'name': 'Dahlia Jansson',
#   'time': '5:48.02',
#   'record': None,
#   'school': 'Ballard',
#   'meet': 'Birger Solberg Invitational',
#   'date': 'Apr 8, 2023',
#   'gender': 'Womens'},
#  {'place': 26,
#   'grade': 10,
#   'name': 'Hannah Capusan',
#   'time': '5:48.74',
#   'record': None,
#   'school': 'Cedar Park Chr',
#   'meet': 'Birger Solberg Invitational',
#   'date': 'Apr 8, 2023',
#   'gender': 'Womens'},
#  {'place': 27,
#   'grade': 11,
#   'name': 'Abby Vlahovich',
#   'time': '5:53.90',
#   'record': None,
#   'school': 'Sedro-Woolley',
#   'meet': 'Birger Solberg Invitational',
#   'date': 'Apr 8, 2023',
#   'gender': 'Womens'},
#  {'place': 28,
#   'grade': 12,
#   'name': 'Sydney Lemke',
#   'time': '5:53.91',
#   'record': None,
#   'school': 'Bellingham',
#   'meet': 'Birger Solberg Invitational',
#   'date': 'Apr 8, 2023',
#   'gender': 'Womens'},
#  {'place': 29,
#   'grade': 9,
#   'name': 'Anna Stchur',
#   'time': '5:54.05',
#   'record': None,
#   'school': 'Bear Creek',
#   'meet': 'Birger Solberg Invitational',
#   'date': 'Apr 8, 2023',
#   'gender': 'Womens'},
#  {'place': 30,
#   'grade': 12,
#   'name': 'Sierra Swart',
#   'time': '5:54.63',
#   'record': None,
#   'school': 'Cedarcrest',
#   'meet': 'Birger Solberg Invitational',
#   'date': 'Apr 8, 2023',
#   'gender': 'Womens'},
#  {'place': 31,
#   'grade': 12,
#   'name': 'Adelaide Nyhan',
#   'time': '5:55.79',
#   'record': None,
#   'school': 'Bush',
#   'meet': 'Birger Solberg Invitational',
#   'date': 'Apr 8, 2023',
#   'gender': 'Womens'},
#  {'place': 32,
#   'grade': 10,
#   'name': 'Jessa Parfet',
#   'time': '5:55.84',
#   'record': None,
#   'school': 'Sehome',
#   'meet': 'Birger Solberg Invitational',
#   'date': 'Apr 8, 2023',
#   'gender': 'Womens'},
#  {'place': 33,
#   'grade': 9,
#   'name': 'Sally Solvang',
#   'time': '5:56.77',
#   'record': None,
#   'school': 'Ballard',
#   'meet': 'Birger Solberg Invitational',
#   'date': 'Apr 8, 2023',
#   'gender': 'Womens'},
#  {'place': 34,
#   'grade': 12,
#   'name': 'Lily Rock',
#   'time': '5:56.92',
#   'record': None,
#   'school': 'Friday Harbor',
#   'meet': 'Birger Solberg Invitational',
#   'date': 'Apr 8, 2023',
#   'gender': 'Womens'},
#  {'place': 35,
#   'grade': 10,
#   'name': 'Sonita Chen',
#   'time': '5:57.97',
#   'record': None,
#   'school': 'Mountlake Terrace',
#   'meet': 'Birger Solberg Invitational',
#   'date': 'Apr 8, 2023',
#   'gender': 'Womens'},
#  {'place': 36,
#   'grade': 9,
#   'name': 'Brooke Berry',
#   'time': '6:01.95',
#   'record': None,
#   'school': 'Stanwood',
#   'meet': 'Birger Solberg Invitational',
#   'date': 'Apr 8, 2023',
#   'gender': 'Womens'},
#  {'place': 37,
#   'grade': 11,
#   'name': 'Rebecca Rhodes',
#   'time': '6:02.39',
#   'record': 'SR',
#   'school': 'Shorecrest',
#   'meet': 'Birger Solberg Invitational',
#   'date': 'Apr 8, 2023',
#   'gender': 'Womens'},
#  {'place': 38,
#   'grade': 10,
#   'name': 'Holland Young',
#   'time': '6:02.80',
#   'record': None,
#   'school': 'Ballard',
#   'meet': 'Birger Solberg Invitational',
#   'date': 'Apr 8, 2023',
#   'gender': 'Womens'},
#  {'place': 39,
#   'grade': 12,
#   'name': 'Annalisa Grant',
#   'time': '6:03.33',
#   'record': None,
#   'school': 'Meadowdale',
#   'meet': 'Birger Solberg Invitational',
#   'date': 'Apr 8, 2023',
#   'gender': 'Womens'},
#  {'place': 40,
#   'grade': 11,
#   'name': 'Kylie Sahatdjian',
#   'time': '6:03.41',
#   'record': None,
#   'school': 'Lakewood',
#   'meet': 'Birger Solberg Invitational',
#   'date': 'Apr 8, 2023',
#   'gender': 'Womens'},
#  {'place': 41,
#   'grade': 9,
#   'name': 'Lyla Hutson',
#   'time': '6:04.94',
#   'record': None,
#   'school': 'South Whidbey',
#   'meet': 'Birger Solberg Invitational',
#   'date': 'Apr 8, 2023',
#   'gender': 'Womens'},
#  {'place': 42,
#   'grade': 9,
#   'name': 'Analycia Zavala',
#   'time': '6:08.28',
#   'record': 'PR',
#   'school': 'Henry Jackson',
#   'meet': 'Birger Solberg Invitational',
#   'date': 'Apr 8, 2023',
#   'gender': 'Womens'},
#  {'place': 43,
#   'grade': 12,
#   'name': 'Erin Gardner',
#   'time': '6:08.56',
#   'record': None,
#   'school': 'Bellingham',
#   'meet': 'Birger Solberg Invitational',
#   'date': 'Apr 8, 2023',
#   'gender': 'Womens'},
#  {'place': 44,
#   'grade': 10,
#   'name': 'Ava May Wenzel',
#   'time': '6:09.38',
#   'record': None,
#   'school': 'Sehome',
#   'meet': 'Birger Solberg Invitational',
#   'date': 'Apr 8, 2023',
#   'gender': 'Womens'},
#  {'place': 45,
#   'grade': 9,
#   'name': 'Jiani Liu',
#   'time': '6:10.71',
#   'record': 'PR',
#   'school': 'North Creek',
#   'meet': 'Birger Solberg Invitational',
#   'date': 'Apr 8, 2023',
#   'gender': 'Womens'},
#  {'place': 46,
#   'grade': 10,
#   'name': 'Azura Munson',
#   'time': '6:11.29',
#   'record': None,
#   'school': 'Ingraham',
#   'meet': 'Birger Solberg Invitational',
#   'date': 'Apr 8, 2023',
#   'gender': 'Womens'},
#  {'place': 47,
#   'grade': 10,
#   'name': 'Marin Lambert',
#   'time': '6:11.88',
#   'record': None,
#   'school': 'Henry Jackson',
#   'meet': 'Birger Solberg Invitational',
#   'date': 'Apr 8, 2023',
#   'gender': 'Womens'},
#  {'place': 48,
#   'grade': 10,
#   'name': 'Charlotte Wenrick',
#   'time': '6:15.01',
#   'record': None,
#   'school': 'Ballard',
#   'meet': 'Birger Solberg Invitational',
#   'date': 'Apr 8, 2023',
#   'gender': 'Womens'},
#  {'place': 49,
#   'grade': 11,
#   'name': 'Charlie Jones',
#   'time': '6:15.46',
#   'record': None,
#   'school': 'Ballard',
#   'meet': 'Birger Solberg Invitational',
#   'date': 'Apr 8, 2023',
#   'gender': 'Womens'},
#  {'place': 51,
#   'grade': 9,
#   'name': 'Christina Thomas',
#   'time': '6:17.83',
#   'record': 'PR',
#   'school': 'Newport (Bellevue)',
#   'meet': 'Birger Solberg Invitational',
#   'date': 'Apr 8, 2023',
#   'gender': 'Womens'},
#  {'place': 52,
#   'grade': 10,
#   'name': 'Harneet Pandher',
#   'time': '6:17.92',
#   'record': None,
#   'school': 'Henry Jackson',
#   'meet': 'Birger Solberg Invitational',
#   'date': 'Apr 8, 2023',
#   'gender': 'Womens'},
#  {'place': 53,
#   'grade': 11,
#   'name': 'Lynn Le',
#   'time': '6:19.42',
#   'record': None,
#   'school': 'Meadowdale',
#   'meet': 'Birger Solberg Invitational',
#   'date': 'Apr 8, 2023',
#   'gender': 'Womens'},
#  {'place': 54,
#   'grade': 9,
#   'name': 'Sabina Kolovyansky',
#   'time': '6:20.40',
#   'record': None,
#   'school': 'Sammamish',
#   'meet': 'Birger Solberg Invitational',
#   'date': 'Apr 8, 2023',
#   'gender': 'Womens'},
#  {'place': 55,
#   'grade': 9,
#   'name': 'Chelsi Pitman',
#   'time': '6:25.51',
#   'record': 'PR',
#   'school': 'Friday Harbor',
#   'meet': 'Birger Solberg Invitational',
#   'date': 'Apr 8, 2023',
#   'gender': 'Womens'},
#  {'place': 56,
#   'grade': 11,
#   'name': 'Ella Nestingen',
#   'time': '6:27.21',
#   'record': None,
#   'school': 'Garfield',
#   'meet': 'Birger Solberg Invitational',
#   'date': 'Apr 8, 2023',
#   'gender': 'Womens'},
#  {'place': 57,
#   'grade': 10,
#   'name': 'Diana Arteaga',
#   'time': '6:31.17',
#   'record': None,
#   'school': 'North Creek',
#   'meet': 'Birger Solberg Invitational',
#   'date': 'Apr 8, 2023',
#   'gender': 'Womens'},
#  {'place': 58,
#   'grade': 12,
#   'name': 'Paili Airth',
#   'time': '6:32.23',
#   'record': None,
#   'school': 'Sehome',
#   'meet': 'Birger Solberg Invitational',
#   'date': 'Apr 8, 2023',
#   'gender': 'Womens'},
#  {'place': 59,
#   'grade': 10,
#   'name': 'Elizabeth Farrell',
#   'time': '6:55.14',
#   'record': None,
#   'school': 'Mount Baker',
#   'meet': 'Birger Solberg Invitational',
#   'date': 'Apr 8, 2023',
#   'gender': 'Womens'}]

# %%
import glob
import csv

all_finishes = []
for filename in glob.glob('datasets/tf-1600/*.txt'):
    all_finishes.extend(read_meet_file(filename))

outfile = 'datasets/results.csv'
with open(outfile, 'w') as csvfile:
    fieldnames = ['school','gender','name','grade','time','place','record','meet','date']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    for finish in all_finishes:
        writer.writerow(finish)

print("wrote",len(all_finishes),"finishes to",outfile)
# Out:
# wrote 292 finishes to datasets/results.csv

# %% [markdown]
# What questions could this data potentially answer?
# - How much faster (or slower) is the average senior vs. freshman?
# - ...
